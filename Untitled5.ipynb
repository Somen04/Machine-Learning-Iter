# %%
import pandas as pd
import numpy as np

# %%
data={'rank':[1,2,4,7,1,5,5,1],
     'marks':[100,99,89,70,100,65,65,99]}
df=pd.DataFrame(data)
df
# Out:
#    rank  marks
# 0     1    100
# 1     2     99
# 2     4     89
# 3     7     70
# 4     1    100
# 5     5     65
# 6     5     65
# 7     1     99

# %%
df[df.duplicated()]
# Out:
#    rank  marks
# 4     1    100
# 6     5     65

# %%
df.drop_duplicates(keep='first')
# Out:
#    rank  marks
# 0     1    100
# 1     2     99
# 2     4     89
# 3     7     70
# 5     5     65
# 7     1     99

# %%
df.drop_duplicates(keep=False)
# Out:
#    rank  marks
# 1     2     99
# 2     4     89
# 3     7     70
# 7     1     99

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df['rank'].unique()
# Out:
# array([1, 2, 4, 7, 5])

# %%
df.drop_duplicates('rank')
# Out:
#    rank  marks
# 0     1    100
# 1     2     99
# 2     4     89
# 3     7     70
# 5     5     65

# %%
c=[[35,5],[10,50]]
c
# Out:
# [[35, 5], [10, 50]]
